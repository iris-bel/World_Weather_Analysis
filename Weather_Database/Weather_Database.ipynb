# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
# Out:
# <zip object at 0x0000016786C9EDC8>

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate [0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(3)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')           
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amalapuram
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | nome
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | flinders
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | arlit
# Processing Record 10 of Set 1 | bud
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | esso
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | port augusta
# Processing Record 20 of Set 1 | kloulklubed
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | altay
# Processing Record 25 of Set 1 | tantoyuca
# Processing Record 26 of Set 1 | rawson
# Processing Record 27 of Set 1 | chukhloma
# Processing Record 28 of Set 1 | camacha
# Processing Record 29 of Set 1 | lorengau
# Processing Record 30 of Set 1 | luorong
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | tirumullaivasal
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 1 | challans
# Processing Record 37 of Set 1 | alta floresta
# Processing Record 38 of Set 1 | vila velha
# Processing Record 39 of Set 1 | nyurba
# Processing Record 40 of Set 1 | raga
# Processing Record 41 of Set 1 | poum
# Processing Record 42 of Set 1 | cap-aux-meules
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | dieppe
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | pangkalanbuun
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | sur
# Processing Record 5 of Set 2 | hasaki
# Processing Record 6 of Set 2 | sobolevo
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | labuhan
# Processing Record 10 of Set 2 | malumfashi
# Processing Record 11 of Set 2 | nizhniy kuranakh
# Processing Record 12 of Set 2 | filadelfia
# Processing Record 13 of Set 2 | ola
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | dzhebariki-khaya
# Processing Record 16 of Set 2 | taoudenni
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 2 | penukonda
# Processing Record 22 of Set 2 | marawi
# Processing Record 23 of Set 2 | winton
# Processing Record 24 of Set 2 | polunochnoye
# Processing Record 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | kendari
# Processing Record 28 of Set 2 | piacabucu
# Processing Record 29 of Set 2 | valparaiso
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | rikitea
# Processing Record 32 of Set 2 | pedasi
# Processing Record 33 of Set 2 | fairbanks
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | samagaltay
# Processing Record 36 of Set 2 | mitu
# Processing Record 37 of Set 2 | xingyi
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | taft
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 2 | porto walter
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | henties bay
# Processing Record 4 of Set 3 | mangrol
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | ridgecrest
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | taylor
# Processing Record 11 of Set 3 | mercedes
# Processing Record 12 of Set 3 | mahanje
# Processing Record 13 of Set 3 | buala
# Processing Record 14 of Set 3 | kaniv
# Processing Record 15 of Set 3 | port hardy
# Processing Record 16 of Set 3 | yatou
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | bara
# Processing Record 20 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 3 | baruun-urt
# Processing Record 22 of Set 3 | conneaut
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | krasnogorodsk
# Processing Record 25 of Set 3 | adrar
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | coahuayana
# Processing Record 28 of Set 3 | mamlyutka
# Processing Record 29 of Set 3 | belaya gora
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 3 | yalutorovsk
# Processing Record 36 of Set 3 | paamiut
# Processing Record 37 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 3 | port-gentil
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | atherton
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | neuquen
# Processing Record 44 of Set 3 | komsomolskiy
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 3 | markova
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | araouane
# Processing Record 1 of Set 4 | lewisville
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | kaeo
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | iberia
# Processing Record 6 of Set 4 | phibun mangsahan
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | inirida
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | contamana
# Processing Record 11 of Set 4 | panguipulli
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | bathsheba
# Processing Record 15 of Set 4 | bad munstereifel
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | ardakan
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | gostilitsy
# Processing Record 21 of Set 4 | benjamin constant
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | mehamn
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | isla vista
# Processing Record 28 of Set 4 | naples
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | tutoia
# Processing Record 31 of Set 4 | zyryanka
# Processing Record 32 of Set 4 | mancio lima
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | tyukhtet
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | beringovskiy
# Processing Record 37 of Set 4 | beidao
# Processing Record 38 of Set 4 | karratha
# Processing Record 39 of Set 4 | gonen
# Processing Record 40 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 4 | mana
# Processing Record 42 of Set 4 | mianyang
# Processing Record 43 of Set 4 | narok
# Processing Record 44 of Set 4 | puerto del rosario
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | maarianhamina
# Processing Record 48 of Set 4 | abha
# Processing Record 49 of Set 4 | champerico
# Processing Record 50 of Set 4 | alekseyevka
# Processing Record 1 of Set 5 | ilhabela
# Processing Record 2 of Set 5 | tuktoyaktuk
# Processing Record 3 of Set 5 | petrovsk-zabaykalskiy
# Processing Record 4 of Set 5 | el alto
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | monticello
# Processing Record 7 of Set 5 | mandalgovi
# Processing Record 8 of Set 5 | abnub
# Processing Record 9 of Set 5 | anadyr
# Processing Record 10 of Set 5 | kongolo
# Processing Record 11 of Set 5 | longyearbyen
# Processing Record 12 of Set 5 | nemuro
# Processing Record 13 of Set 5 | chapais
# Processing Record 14 of Set 5 | tecoanapa
# Processing Record 15 of Set 5 | bredasdorp
# Processing Record 16 of Set 5 | kuvshinovo
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | opuwo
# Processing Record 19 of Set 5 | jiayuguan
# Processing Record 20 of Set 5 | harper
# Processing Record 21 of Set 5 | benguela
# Processing Record 22 of Set 5 | guilin
# Processing Record 23 of Set 5 | bowen
# Processing Record 24 of Set 5 | kidal
# Processing Record 25 of Set 5 | ardrossan
# Processing Record 26 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 5 | pacific grove
# Processing Record 28 of Set 5 | buckeye
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | olinda
# Processing Record 31 of Set 5 | roald
# Processing Record 32 of Set 5 | mao
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | oblivskaya
# Processing Record 35 of Set 5 | galle
# Processing Record 36 of Set 5 | loralai
# Processing Record 37 of Set 5 | kishtwar
# Processing Record 38 of Set 5 | maumere
# Processing Record 39 of Set 5 | burica
# City not found. Skipping...
# Processing Record 40 of Set 5 | ambilobe
# Processing Record 41 of Set 5 | aquiraz
# Processing Record 42 of Set 5 | saurimo
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | moerai
# Processing Record 45 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 5 | kedrovyy
# Processing Record 47 of Set 5 | bandundu
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | bayevo
# Processing Record 50 of Set 5 | akdepe
# Processing Record 1 of Set 6 | ganzhou
# Processing Record 2 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 3 of Set 6 | bweyogerere
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | bollnas
# Processing Record 7 of Set 6 | siayan
# Processing Record 8 of Set 6 | bemidji
# Processing Record 9 of Set 6 | nelson bay
# Processing Record 10 of Set 6 | inuvik
# Processing Record 11 of Set 6 | san carlos del zulia
# Processing Record 12 of Set 6 | fort nelson
# Processing Record 13 of Set 6 | ponta delgada
# Processing Record 14 of Set 6 | birao
# Processing Record 15 of Set 6 | mazamari
# Processing Record 16 of Set 6 | alice springs
# Processing Record 17 of Set 6 | korla
# Processing Record 18 of Set 6 | ha tinh
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | pangody
# Processing Record 21 of Set 6 | kirakira
# Processing Record 22 of Set 6 | soanierana ivongo
# Processing Record 23 of Set 6 | mandiana
# Processing Record 24 of Set 6 | andros town
# Processing Record 25 of Set 6 | geraldton
# Processing Record 26 of Set 6 | kayerkan
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | peniche
# Processing Record 29 of Set 6 | boa vista
# Processing Record 30 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 6 | ocampo
# Processing Record 32 of Set 6 | christchurch
# Processing Record 33 of Set 6 | kara-tyube
# Processing Record 34 of Set 6 | gizo
# Processing Record 35 of Set 6 | mayo
# Processing Record 36 of Set 6 | bitlis
# Processing Record 37 of Set 6 | hovd
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | yashkul
# Processing Record 40 of Set 6 | imeni poliny osipenko
# Processing Record 41 of Set 6 | hailey
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | umba
# Processing Record 44 of Set 6 | manggar
# Processing Record 45 of Set 6 | ribeira grande
# Processing Record 46 of Set 6 | puri
# Processing Record 47 of Set 6 | sao miguel
# Processing Record 48 of Set 6 | pingliang
# Processing Record 49 of Set 6 | castlemaine
# Processing Record 50 of Set 6 | lianran
# Processing Record 1 of Set 7 | dallas
# Processing Record 2 of Set 7 | broome
# Processing Record 3 of Set 7 | brownsville
# Processing Record 4 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 7 | west bay
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | salalah
# Processing Record 8 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 7 | guira de melena
# Processing Record 10 of Set 7 | killybegs
# Processing Record 11 of Set 7 | newport
# Processing Record 12 of Set 7 | tilichiki
# Processing Record 13 of Set 7 | yerbogachen
# Processing Record 14 of Set 7 | paratinga
# Processing Record 15 of Set 7 | bereda
# Processing Record 16 of Set 7 | tukrah
# Processing Record 17 of Set 7 | kiama
# Processing Record 18 of Set 7 | arraial do cabo
# Processing Record 19 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | nishihara
# Processing Record 22 of Set 7 | fez
# Processing Record 23 of Set 7 | sebinkarahisar
# Processing Record 24 of Set 7 | tasiilaq
# Processing Record 25 of Set 7 | mineros
# Processing Record 26 of Set 7 | lavrentiya
# Processing Record 27 of Set 7 | lanzhou
# Processing Record 28 of Set 7 | quang ngai
# Processing Record 29 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | avera
# Processing Record 31 of Set 7 | ryotsu
# Processing Record 32 of Set 7 | campo maior
# Processing Record 33 of Set 7 | tazovskiy
# Processing Record 34 of Set 7 | gat
# Processing Record 35 of Set 7 | ishigaki
# Processing Record 36 of Set 7 | kutum
# Processing Record 37 of Set 7 | half moon bay
# Processing Record 38 of Set 7 | urengoy
# Processing Record 39 of Set 7 | gorontalo
# Processing Record 40 of Set 7 | muzhi
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | homer
# Processing Record 43 of Set 7 | nagyigmand
# Processing Record 44 of Set 7 | byron bay
# Processing Record 45 of Set 7 | sovetskiy
# Processing Record 46 of Set 7 | santa maria
# Processing Record 47 of Set 7 | chifeng
# Processing Record 48 of Set 7 | luganville
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | kashan
# Processing Record 1 of Set 8 | fort morgan
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | cao bang
# Processing Record 4 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 5 of Set 8 | bilasipara
# Processing Record 6 of Set 8 | tubingen
# City not found. Skipping...
# Processing Record 7 of Set 8 | japura
# Processing Record 8 of Set 8 | dingle
# Processing Record 9 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 8 | agaro
# Processing Record 11 of Set 8 | kavaratti
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | raul soares
# Processing Record 14 of Set 8 | zabol
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | faanui
# Processing Record 17 of Set 8 | saint anthony
# Processing Record 18 of Set 8 | birjand
# Processing Record 19 of Set 8 | nantucket
# Processing Record 20 of Set 8 | omboue
# Processing Record 21 of Set 8 | libertador general san martin
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | yining
# Processing Record 24 of Set 8 | namatanai
# Processing Record 25 of Set 8 | carmen
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | zhanaozen
# Processing Record 28 of Set 8 | bogorodskoye
# Processing Record 29 of Set 8 | matagami
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | oranjemund
# Processing Record 32 of Set 8 | lebork
# Processing Record 33 of Set 8 | desnogorsk
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | teguldet
# Processing Record 37 of Set 8 | vanimo
# Processing Record 38 of Set 8 | kruisfontein
# Processing Record 39 of Set 8 | isiro
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | haines junction
# Processing Record 42 of Set 8 | cam ranh
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | fereydun kenar
# Processing Record 45 of Set 8 | odweyne
# Processing Record 46 of Set 8 | warangal
# Processing Record 47 of Set 8 | dwarka
# Processing Record 48 of Set 8 | palmer
# Processing Record 49 of Set 8 | synya
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | humboldt
# Processing Record 2 of Set 9 | kranjska gora
# Processing Record 3 of Set 9 | yar-sale
# Processing Record 4 of Set 9 | siloam springs
# Processing Record 5 of Set 9 | el cope
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | hammerfest
# Processing Record 8 of Set 9 | ayagoz
# Processing Record 9 of Set 9 | san vicente de canete
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | rocha
# Processing Record 12 of Set 9 | lagoa
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | necochea
# Processing Record 15 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 9 | sigayevo
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | boyolangu
# Processing Record 19 of Set 9 | darnah
# Processing Record 20 of Set 9 | talnakh
# Processing Record 21 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 9 | pocone
# Processing Record 23 of Set 9 | elkton
# Processing Record 24 of Set 9 | vinh yen
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | tateyama
# Processing Record 27 of Set 9 | margate
# Processing Record 28 of Set 9 | san jeronimo
# Processing Record 29 of Set 9 | comodoro rivadavia
# Processing Record 30 of Set 9 | partsa
# Processing Record 31 of Set 9 | porto novo
# Processing Record 32 of Set 9 | permet
# Processing Record 33 of Set 9 | zaysan
# Processing Record 34 of Set 9 | kariba
# Processing Record 35 of Set 9 | chernyshevskiy
# Processing Record 36 of Set 9 | andenes
# Processing Record 37 of Set 9 | bermejo
# Processing Record 38 of Set 9 | seybaplaya
# Processing Record 39 of Set 9 | ak-dovurak
# Processing Record 40 of Set 9 | saldanha
# Processing Record 41 of Set 9 | la ronge
# Processing Record 42 of Set 9 | lipin bor
# Processing Record 43 of Set 9 | takoradi
# Processing Record 44 of Set 9 | vysokogornyy
# Processing Record 45 of Set 9 | san vicente
# Processing Record 46 of Set 9 | kavieng
# Processing Record 47 of Set 9 | nevelsk
# Processing Record 48 of Set 9 | ozark
# Processing Record 49 of Set 9 | oktyabrskoye
# Processing Record 50 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 10 | sompeta
# Processing Record 2 of Set 10 | hamilton
# Processing Record 3 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 4 of Set 10 | gashua
# Processing Record 5 of Set 10 | ewa beach
# Processing Record 6 of Set 10 | isangel
# Processing Record 7 of Set 10 | chuy
# Processing Record 8 of Set 10 | buraydah
# Processing Record 9 of Set 10 | palana
# Processing Record 10 of Set 10 | orsha
# Processing Record 11 of Set 10 | marsta
# Processing Record 12 of Set 10 | montrose
# Processing Record 13 of Set 10 | niksic
# Processing Record 14 of Set 10 | nhulunbuy
# Processing Record 15 of Set 10 | egvekinot
# Processing Record 16 of Set 10 | kailua
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | rybachiy
# Processing Record 19 of Set 10 | san quintin
# Processing Record 20 of Set 10 | staryy nadym
# Processing Record 21 of Set 10 | langsa
# Processing Record 22 of Set 10 | muyezerskiy
# Processing Record 23 of Set 10 | saint-joseph
# Processing Record 24 of Set 10 | dunedin
# Processing Record 25 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 26 of Set 10 | inhambane
# Processing Record 27 of Set 10 | kyzyl-suu
# Processing Record 28 of Set 10 | mayumba
# Processing Record 29 of Set 10 | plettenberg bay
# Processing Record 30 of Set 10 | padang
# Processing Record 31 of Set 10 | iqaluit
# Processing Record 32 of Set 10 | watsa
# Processing Record 33 of Set 10 | hun
# Processing Record 34 of Set 10 | bubaque
# Processing Record 35 of Set 10 | tungor
# Processing Record 36 of Set 10 | kousseri
# Processing Record 37 of Set 10 | yakeshi
# Processing Record 38 of Set 10 | coquimbo
# Processing Record 39 of Set 10 | turukhansk
# Processing Record 40 of Set 10 | hobyo
# Processing Record 41 of Set 10 | minuri
# Processing Record 42 of Set 10 | north bend
# Processing Record 43 of Set 10 | tuatapere
# Processing Record 44 of Set 10 | atikokan
# Processing Record 45 of Set 10 | harnosand
# Processing Record 46 of Set 10 | bhadasar
# Processing Record 47 of Set 10 | malanje
# Processing Record 48 of Set 10 | sao felix do xingu
# Processing Record 49 of Set 10 | tarabuco
# Processing Record 50 of Set 10 | ludvika
# Processing Record 1 of Set 11 | indian head
# Processing Record 2 of Set 11 | mookane
# Processing Record 3 of Set 11 | yeppoon
# Processing Record 4 of Set 11 | severnoye
# Processing Record 5 of Set 11 | sztum
# Processing Record 6 of Set 11 | erenhot
# Processing Record 7 of Set 11 | agadez
# Processing Record 8 of Set 11 | tshikapa
# Processing Record 9 of Set 11 | viamao
# Processing Record 10 of Set 11 | college
# Processing Record 11 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 11 | rodrigues alves
# Processing Record 13 of Set 11 | sa kaeo
# Processing Record 14 of Set 11 | nema
# Processing Record 15 of Set 11 | sungairaya
# Processing Record 16 of Set 11 | jacareacanga
# Processing Record 17 of Set 11 | metro
# Processing Record 18 of Set 11 | seddon
# Processing Record 19 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 11 | krasnyy chikoy
# Processing Record 21 of Set 11 | renfrew
# Processing Record 22 of Set 11 | catamarca
# Processing Record 23 of Set 11 | lander
# Processing Record 24 of Set 11 | port-cartier
# Processing Record 25 of Set 11 | mayskiy
# Processing Record 26 of Set 11 | grand gaube
# Processing Record 27 of Set 11 | bethel
# Processing Record 28 of Set 11 | zykovo
# Processing Record 29 of Set 11 | huilong
# Processing Record 30 of Set 11 | vila
# Processing Record 31 of Set 11 | brae
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | rafai
# Processing Record 34 of Set 11 | sorland
# Processing Record 35 of Set 11 | maltahohe
# Processing Record 36 of Set 11 | normandin
# Processing Record 37 of Set 11 | shiloh
# Processing Record 38 of Set 11 | maiduguri
# Processing Record 39 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 40 of Set 11 | sibolga
# Processing Record 41 of Set 11 | intipuca
# Processing Record 42 of Set 11 | obo
# Processing Record 43 of Set 11 | punta alta
# Processing Record 44 of Set 11 | iranduba
# Processing Record 45 of Set 11 | hami
# Processing Record 46 of Set 11 | chengzihe
# Processing Record 47 of Set 11 | medea
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | batagay-alyta
# Processing Record 50 of Set 11 | muroto
# Processing Record 1 of Set 12 | gaurela
# Processing Record 2 of Set 12 | catia la mar
# Processing Record 3 of Set 12 | isla mujeres
# Processing Record 4 of Set 12 | klaksvik
# Processing Record 5 of Set 12 | tigil
# Processing Record 6 of Set 12 | myitkyina
# Processing Record 7 of Set 12 | kuching
# Processing Record 8 of Set 12 | vorotynets
# Processing Record 9 of Set 12 | grindavik
# Processing Record 10 of Set 12 | gairo
# Processing Record 11 of Set 12 | dukat
# Processing Record 12 of Set 12 | russell
# Processing Record 13 of Set 12 | sturgeon bay
# Processing Record 14 of Set 12 | invermere
# Processing Record 15 of Set 12 | moron
# Processing Record 16 of Set 12 | broken hill
# Processing Record 17 of Set 12 | berbera
# Processing Record 18 of Set 12 | iralaya
# Processing Record 19 of Set 12 | kishorganj
# Processing Record 20 of Set 12 | adre
# Processing Record 21 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 12 | san nicolas
# Processing Record 23 of Set 12 | marsa matruh
# Processing Record 24 of Set 12 | solnechnyy
# Processing Record 25 of Set 12 | batsfjord
# Processing Record 26 of Set 12 | dakar
# Processing Record 27 of Set 12 | santa cruz cabralia
# Processing Record 28 of Set 12 | nacala
# Processing Record 29 of Set 12 | asosa
# Processing Record 30 of Set 12 | portland
# Processing Record 31 of Set 12 | smederevska palanka
# Processing Record 32 of Set 12 | meulaboh
# Processing Record 33 of Set 12 | colesberg
# Processing Record 34 of Set 12 | huainan
# Processing Record 35 of Set 12 | ulaangom
# Processing Record 36 of Set 12 | talcahuano
# Processing Record 37 of Set 12 | buriti bravo
# Processing Record 38 of Set 12 | rehnan
# Processing Record 39 of Set 12 | leh
# Processing Record 40 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 12 | ihosy
# Processing Record 43 of Set 12 | kyren
# Processing Record 44 of Set 12 | saint-augustin
# Processing Record 45 of Set 12 | belousovka
# Processing Record 46 of Set 12 | pilar
# Processing Record 47 of Set 12 | olafsvik
# Processing Record 48 of Set 12 | wanaka
# Processing Record 49 of Set 12 | suda
# Processing Record 50 of Set 12 | trairi
# Processing Record 1 of Set 13 | sainthia
# Processing Record 2 of Set 13 | lincoln
# Processing Record 3 of Set 13 | kaseda
# Processing Record 4 of Set 13 | kropotkin
# Processing Record 5 of Set 13 | karaton
# Processing Record 6 of Set 13 | lityn
# Processing Record 7 of Set 13 | pedernales
# Processing Record 8 of Set 13 | chiredzi
# Processing Record 9 of Set 13 | chiknayakanhalli
# Processing Record 10 of Set 13 | mizan teferi
# Processing Record 11 of Set 13 | iquitos
# Processing Record 12 of Set 13 | sembe
# Processing Record 13 of Set 13 | turayf
# Processing Record 14 of Set 13 | samarai
# Processing Record 15 of Set 13 | goderich
# Processing Record 16 of Set 13 | semporna
# Processing Record 17 of Set 13 | bassano
# Processing Record 18 of Set 13 | talcher
# Processing Record 19 of Set 13 | bismarck
# Processing Record 20 of Set 13 | kargasok
# Processing Record 21 of Set 13 | hokitika
# Processing Record 22 of Set 13 | bandarbeyla
# Processing Record 23 of Set 13 | itaituba
# Processing Record 24 of Set 13 | shimoda
# Processing Record 25 of Set 13 | atar
# Processing Record 26 of Set 13 | mabaruma
# Processing Record 27 of Set 13 | ucluelet
# Processing Record 28 of Set 13 | calvinia
# Processing Record 29 of Set 13 | aitape
# Processing Record 30 of Set 13 | colwyn bay
# Processing Record 31 of Set 13 | mvuma
# Processing Record 32 of Set 13 | we
# City not found. Skipping...
# Processing Record 33 of Set 13 | jingcheng
# Processing Record 34 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 13 | benjamin aceval
# Processing Record 36 of Set 13 | wajima
# Processing Record 37 of Set 13 | los llanos de aridane
# Processing Record 38 of Set 13 | lashio
# Processing Record 39 of Set 13 | alghero
# Processing Record 40 of Set 13 | goma
# Processing Record 41 of Set 13 | leningradskiy
# Processing Record 42 of Set 13 | pozo colorado
# Processing Record 43 of Set 13 | shingu
# Processing Record 44 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 13 | te anau
# Processing Record 46 of Set 13 | viedma
# Processing Record 47 of Set 13 | nokaneng
# Processing Record 48 of Set 13 | olga
# Processing Record 49 of Set 13 | aykhal
# Processing Record 50 of Set 13 | greenwood
# Processing Record 1 of Set 14 | skelleftea
# Processing Record 2 of Set 14 | altamira
# Processing Record 3 of Set 14 | duz
# City not found. Skipping...
# Processing Record 4 of Set 14 | plouzane
# Processing Record 5 of Set 14 | cape coast
# Processing Record 6 of Set 14 | berlevag
# Processing Record 7 of Set 14 | cascavel
# Processing Record 8 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 14 | marzuq
# Processing Record 11 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 14 | rybnaya sloboda
# Processing Record 13 of Set 14 | poopo
# Processing Record 14 of Set 14 | kaduqli
# Processing Record 15 of Set 14 | ous
# Processing Record 16 of Set 14 | senanga
# Processing Record 17 of Set 14 | port moresby
# Processing Record 18 of Set 14 | pizarro
# Processing Record 19 of Set 14 | pathein
# Processing Record 20 of Set 14 | kurilsk
# Processing Record 21 of Set 14 | tuban
# Processing Record 22 of Set 14 | vestmannaeyjar
# Processing Record 23 of Set 14 | belyy yar
# Processing Record 24 of Set 14 | guymon
# Processing Record 25 of Set 14 | orlik
# Processing Record 26 of Set 14 | skrunda
# Processing Record 27 of Set 14 | dublin
# Processing Record 28 of Set 14 | pacocha
# Processing Record 29 of Set 14 | richards bay
# Processing Record 30 of Set 14 | boende
# Processing Record 31 of Set 14 | bodmin
# Processing Record 32 of Set 14 | itambacuri
# Processing Record 33 of Set 14 | ayan
# Processing Record 34 of Set 14 | itarema
# Processing Record 35 of Set 14 | rudnichnyy
# Processing Record 36 of Set 14 | rapid valley
# Processing Record 37 of Set 14 | baykit
# Processing Record 38 of Set 14 | oussouye
# Processing Record 39 of Set 14 | mpika
# Processing Record 40 of Set 14 | vicosa
# Processing Record 41 of Set 14 | araceli
# Processing Record 42 of Set 14 | yongzhou
# Processing Record 43 of Set 14 | borogontsy
# Processing Record 44 of Set 14 | garowe
# Processing Record 45 of Set 14 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 46 of Set 14 | ulladulla
# Processing Record 47 of Set 14 | ndele
# Processing Record 48 of Set 14 | key largo
# Processing Record 49 of Set 14 | tadine
# Processing Record 50 of Set 14 | bacolod
# Processing Record 1 of Set 15 | hailar
# Processing Record 2 of Set 15 | springbok
# Processing Record 3 of Set 15 | price
# Processing Record 4 of Set 15 | eyl
# Processing Record 5 of Set 15 | vanavara
# Processing Record 6 of Set 15 | conceicao do araguaia
# Processing Record 7 of Set 15 | estancia
# Processing Record 8 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 15 | uinskoye
# Processing Record 10 of Set 15 | matamoros
# Processing Record 11 of Set 15 | havoysund
# Processing Record 12 of Set 15 | thunder bay
# Processing Record 13 of Set 15 | nuevo progreso
# Processing Record 14 of Set 15 | mocuba
# Processing Record 15 of Set 15 | nabire
# Processing Record 16 of Set 15 | narayanavanam
# Processing Record 17 of Set 15 | san policarpo
# Processing Record 18 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 15 | cravo norte
# Processing Record 20 of Set 15 | briancon
# Processing Record 21 of Set 15 | cabedelo
# Processing Record 22 of Set 15 | chivolo
# Processing Record 23 of Set 15 | tres arroyos
# Processing Record 24 of Set 15 | birin
# Processing Record 25 of Set 15 | nybro
# Processing Record 26 of Set 15 | terney
# Processing Record 27 of Set 15 | calabozo
# Processing Record 28 of Set 15 | port macquarie
# Processing Record 29 of Set 15 | eenhana
# Processing Record 30 of Set 15 | ndjole
# Processing Record 31 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 15 | damara
# Processing Record 33 of Set 15 | mpongwe
# Processing Record 34 of Set 15 | mackay
# Processing Record 35 of Set 15 | areosa
# Processing Record 36 of Set 15 | kuhestan
# City not found. Skipping...
# Processing Record 37 of Set 15 | vao
# Processing Record 38 of Set 15 | bereznik
# Processing Record 39 of Set 15 | naantali
# Processing Record 40 of Set 15 | rancho palos verdes
# Processing Record 41 of Set 15 | sisimiut
# Processing Record 42 of Set 15 | pandan
# Processing Record 43 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 15 | nkoteng
# Processing Record 45 of Set 15 | whitehorse
# Processing Record 46 of Set 15 | morrelganj
# City not found. Skipping...
# Processing Record 47 of Set 15 | nan
# Processing Record 48 of Set 15 | carutapera
# Processing Record 49 of Set 15 | sokolo
# Processing Record 50 of Set 15 | toamasina
# Processing Record 1 of Set 16 | samfya
# Processing Record 2 of Set 16 | luau
# Processing Record 3 of Set 16 | fengrun
# Processing Record 4 of Set 16 | bahadurgarh
# Processing Record 5 of Set 16 | cantagallo
# Processing Record 6 of Set 16 | san cristobal
# Processing Record 7 of Set 16 | muisne
# Processing Record 8 of Set 16 | soe
# Processing Record 9 of Set 16 | durres
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Amalapuram  16.5833   82.0167     72.21        88           3
# 1     Mahebourg -20.4081   57.7000     74.25        83          40
# 2  Norman Wells  65.2820 -126.8329      1.35        93         100
# 3          Nome  64.5011 -165.4064     24.87        81         100
# 4       Mataura -46.1927  168.8643     50.49        53          81
# 5      Flinders -34.5833  150.8552     66.06        79         100
# 6        Albany  42.6001  -73.9662     51.26        93         100
# 7     Busselton -33.6500  115.3333     62.08        81          99
# 8         Arlit  18.7369    7.3853     71.51        19           0
# 9           Bud  39.4470  -86.1758     36.46        59           0
#
#    Wind Speed Country                 Date Current Description
# 0        4.03      IN  2022-11-30 21:07:26           clear sky
# 1        2.30      MU  2022-11-30 21:04:12    scattered clouds
# 2        2.68      CA  2022-11-30 21:05:09          light snow
# 3       10.36      US  2022-11-30 21:11:04                snow
# 4        6.93      NZ  2022-11-30 21:01:14       broken clouds
# 5        4.00      AU  2022-11-30 21:05:57     overcast clouds
# 6        1.01      US  2022-11-30 21:01:55       moderate rain
# 7        9.28      AU  2022-11-30 21:04:35     overcast clouds
# 8        7.09      NE  2022-11-30 21:11:05           clear sky
# 9       17.22      US  2022-11-30 21:11:06           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Amalapuram      IN  16.5833   82.0167     72.21        88           3
# 1        Mahebourg      MU -20.4081   57.7000     74.25        83          40
# 2     Norman Wells      CA  65.2820 -126.8329      1.35        93         100
# 3             Nome      US  64.5011 -165.4064     24.87        81         100
# 4          Mataura      NZ -46.1927  168.8643     50.49        53          81
# ..             ...     ...      ...       ...       ...       ...         ...
# 696     Cantagallo      CO   7.3760  -73.9196     83.25        75          94
# 697  San Cristobal      VE   7.7669  -72.2250     71.78        73          49
# 698         Muisne      EC   0.6000  -80.0333     77.41        76          66
# 699            Soe      ID  -9.8607  124.2840     66.18        90         100
# 700         Durres      AL  41.3231   19.4414     48.38        68         100
#
#      Wind Speed Current Description
# 0          4.03           clear sky
# 1          2.30    scattered clouds
# 2          2.68          light snow
# 3         10.36                snow
# 4          6.93       broken clouds
# ..          ...                 ...
# 696        2.06     overcast clouds
# 697        5.55    scattered clouds
# 698       11.12       broken clouds
# 699        2.53     overcast clouds
# 700        8.59     overcast clouds
#
# [701 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
